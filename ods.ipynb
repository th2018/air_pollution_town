# %%
from pyexcel_ods import get_data
import pandas as pd
#from pandas_ods_reader import read_ods
import json

# %% [markdown]
# https://www.forestresearch.gov.uk/tools-and-resources/statistics/data-downloads/

# %%
data = get_data(r"C:\Users\taohuang\Downloads\ch4_carbon_fs2021.ods")

# %%
data
# Out:
# OrderedDict([('Cover',
#               [['Forestry Statistics 2021: Carbon'],
#                [],
#                ['Release date:  30 September 2021'],
#                [],
#                ['Forestry Statistics is a compilation of statistics on woodland, forestry and primary wood processing in the UK.  It is available from the Forest Research website at:'],
#                ['www.forestresearch.gov.uk/tools-and-resources/statistics/forestry-statistics/'],
#                [],
#                ['This spreadsheet provides copies of tables and data for charts that are shown in:'],
#                ['Chapter 4 - Carbon'],
#                [],
#                ['List of Tables'],
#                ['Table 4.1a  UK Forest carbon stock'],
#                ['Table 4.1b  Forest carbon stock by country, 2020'],
#                ['Table 4.2  Net annual change in carbon (CO2 equivalent) in UK woodlands'],
# ...

# %%
type(data)
# Out:
# collections.OrderedDict

# %%
 print(json.dumps(data))
# Out:
# {"Cover": [["Forestry Statistics 2021: Carbon"], [], ["Release date:  30 September 2021"], [], ["Forestry Statistics is a compilation of statistics on woodland, forestry and primary wood processing in the UK.  It is available from the Forest Research website at:"], ["www.forestresearch.gov.uk/tools-and-resources/statistics/forestry-statistics/"], [], ["This spreadsheet provides copies of tables and data for charts that are shown in:"], ["Chapter 4 - Carbon"], [], ["List of Tables"], ["Table 4.1a  UK Forest carbon stock"], ["Table 4.1b  Forest carbon stock by country, 2020"], ["Table 4.2  Net annual change in carbon (CO2 equivalent) in UK woodlands"], ["Data for Figure 4.1  Net annual change in carbon (CO2 equivalent) in UK woodlands"], ["Table 4.3a  Woodland Carbon Code projects in the UK "], ["Table 4.3b  Woodland Carbon Code projects at 31 March 2021"], ["Table 4.4  Management of UK forests in response to the threat of climate change"], [], ["Next update:  29 September 2022"], [], 
# ...

# %%
data2=pd.read_excel(r"C:\Users\taohuang\Downloads\ch4_carbon_fs2021.ods", engine="odf")

# %%
data2
# Out:
#                      Forestry Statistics 2021: Carbon
# 0                                                 NaN
# 1                    Release date:  30 September 2021
# 2                                                 NaN
# 3   Forestry Statistics is a compilation of statis...
# 4   www.forestresearch.gov.uk/tools-and-resources/...
# 5                                                 NaN
# 6   This spreadsheet provides copies of tables and...
# 7                                  Chapter 4 - Carbon
# 8                                                 NaN
# 9                                      List of Tables
# 10                 Table 4.1a  UK Forest carbon stock
# 11   Table 4.1b  Forest carbon stock by country, 2020
# 12  Table 4.2  Net annual change in carbon (CO2 eq...
# 13  Data for Figure 4.1  Net annual change in carb...
# 14  Table 4.3a  Woodland Carbon Code projects in t...
# 15  Table 4.3b  Woodland Carbon Code projects at 3...
# ...
